# %% [markdown]
# 1. Write a Python program to check that a string contains only a certain set of characters (in this case a-z, A-Z and 0-9).

# %%
import re
text="my name is Linitha and my mail id is lini123@gmail.com"
pattern=r'[a-zA-Z0-9]'
result=re.match(pattern,text)
if result:
  print("string contains only 0-9 A-Z and a-z")
else:
  print("string contains other special characters")
# Out:
# string contains only 0-9 A-Z and a-z

# %% [markdown]
# 2. Write a Python program that matches a string that has an a followed by zero or more b's.

# %%
import re
text="aabba abbi abbaa aabbbii"
pattern=r'ab*'
result=re.findall(pattern,text)
print(result)
# Out:
# ['a', 'abb', 'a', 'abb', 'abb', 'a', 'a', 'a', 'abbb']

# %% [markdown]
# 3. Replace only the first occurrence of 5 with five for the given string

# %%
import re
ip = 'They ate 5 apples and 5 oranges'
result=re.sub('5','five',ip,1)
print(result)
# Out:
# They ate five apples and 5 oranges

# %% [markdown]
# 4. Write a Python program that matches a string that has an a followed by three 'b'.

# %%
import re
text="hi iam abbbaa, hello friends"
pattern=r'\w*a+b{3}w*'
result=re.findall(pattern,text)
print(result)
# Out:
# ['abbb']

# %% [markdown]
# 5. Write a Python program that matches a string that has an 'a' followed by anything ending in 'b'.

# %%
import re
text="hello friends im anub"
pattern=r'\ba[a-z0-9]*b\b'
result=re.findall(pattern,text)
print(result)
# Out:
# ['anub']

# %% [markdown]
# 6. Write a Python program to search for numbers (0-9) of length between 1 and 3 in a given string.

# %%
import re
txt="Exercises number 1, 12, 13, and 345 are important"
pattern=r'[0-9]{1,3}'
result=re.findall(pattern,txt)
print(result)
# Out:
# ['1', '12', '13', '345']

# %% [markdown]
# 7. Write a Python program to search for literal strings within a string.\
# Sample text : 'The quick brown fox jumps over the lazy dog.' \
# Searched words : 'fox', 'dog', 'horse'

# %%
import re
text="The quick brown fox jumps over the lazy dog."
pattern=re.search("fox|dog|horse", text)
if pattern:
  print("it is a match")
else:
  print("it is not match")
# Out:
# it is a match

# %% [markdown]
# 8. Write a Python program to search for a literal string in a string and also find the location within the original string where the pattern occurs.
#
# Sample text : 'The quick brown fox jumps over the lazy dog.' \
# Searched words : 'fox'

# %%
import re
my_string = 'The quick brown fox jumps over the lazy dog.'
pattern = re.search(r'fox', my_string)
print(pattern)
# Out:
# <re.Match object; span=(16, 19), match='fox'>

# %% [markdown]
# 9.  Write a Python program to extract year, month and date from an URL

# %%
import re
url1= "https://www.washingtonpost.com/news/football-insider/wp/2016/09/02/odell-beckhams-fame-rests-on-one-stupid-little-ball-josh-norman-tells-author/"
pattern=r'\d{4}/\d{2}/\d{2}'
x=re.findall(pattern,url1)
print(x)
# Out:
# ['2016/09/02']

# %% [markdown]
# 10. Write a Python program to find URLs in a string.

# %%
import re
text = '<p>Contents :</p><a href="https://w3resource.com">Python Examples</a><a href="http://github.com">Even More Examples</a>'
pattern=r'http\w?://\w+.com'
result=re.findall(pattern,text)
print(result)
# Out:
# ['https://w3resource.com', 'http://github.com']

# %% [markdown]
# 11. Write a Python program to remove the parenthesis area in a string.\
#
# Sample data : ["example (.com)", "w3resource", "github (.com)", "stackoverflow (.com)"] \
# Expected Output: \
# example  \
# w3resource \
# github  \
# stackoverflow. \

# %%
import re
txt= ["example (.com)", "w3resource", "github (.com)", "stackoverflow (.com)"]
pattern=r'\w+[^(com)]'
for i in txt:
  result=re.findall(pattern,i)
  print(" ".join(result))
# Out:
# example
# w3resource
# github
# stackoverflow

# %% [markdown]
# 12. Write a Python program to concatenate the consecutive numbers in a given string. \
#
# Original string:  \
# Enter at 1 20 Kearny Street. The security desk can direct you to floor 1 6. Please have your identification ready.  \
#
# After concatenating the consecutive numbers in the said string:  \
# Enter at 120 Kearny Street. The security desk can direct you to floor 16. Please have your identification ready.

# %%
import re
text = "Enter at 1 20 Kearny Street. The security desk can direct you to floor 1 6. Please have your identification ready."
result=re.sub(r'(?<=\d)\s(?=\d)', '', text)
print(result)
# Out:
# Enter at 120 Kearny Street. The security desk can direct you to floor 16. Please have your identification ready.
